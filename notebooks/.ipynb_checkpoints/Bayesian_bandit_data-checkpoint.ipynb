# %%
import json
import requests
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = 'http://bayesian-bandit.adludio.com/'
r = requests.post(url +'dump_bandit_data', 
    json={'item_group_id_list': ['b5yn8r3', 's2dmtni', 'bwik4qv', '73t0r3u', 'wqgxoc1', 
                                 'u2t9dgi', 'uwyvrja', 'pace1ha', 'vf03dnt', '36b7iyw' ] } )
parsed = json.loads(r.content)
df = pd.DataFrame(parsed['bandit_data']).sort_values('date').reset_index(drop=True).drop(columns='id')
df
# Out:
#       item_id item_group_id        date           created_at  num_success  \
# 0     p673nlk       b5yn8r3  2020-07-27  2021-02-01 18:53:14          235
# 1     yar3gt3       b5yn8r3  2020-07-27  2021-02-01 18:53:14          260
# 2     1wr71gl       b5yn8r3  2020-07-27  2021-02-01 18:53:14          286
# 3     1wr71gl       b5yn8r3  2020-07-28  2021-02-01 18:53:14          349
# 4     p673nlk       b5yn8r3  2020-07-28  2021-02-01 18:53:14          339
# ...       ...           ...         ...                  ...          ...
# 1455  pjiwct6       36b7iyw  2020-12-14  2021-02-01 18:55:19          946
# 1456  0yyr8tx       36b7iyw  2020-12-15  2021-02-01 18:55:19         1399
# 1457  pjiwct6       36b7iyw  2020-12-15  2021-02-01 18:55:19          993
# 1458  0yyr8tx       36b7iyw  2020-12-16  2021-02-01 18:55:20          856
# 1459  pjiwct6       36b7iyw  2020-12-16  2021-02-01 18:55:20          594
#
#       num_trials  num_engagements  num_impressions  num_clickthroughs  \
# 0           3052              235             3052                  5
# 1           2991              260             2991                  4
# 2           2968              286             2968                  9
# 3           3169              349             3169                 11
# 4           3306              339             3306                  2
# ...          ...              ...              ...                ...
# 1455        6132              946             6132                 59
# 1456        9620             1399             9620                 64
# 1457        6077              993             6077                 67
# 1458        4523              856             4523                 30
# 1459        2813              594             2813                 34
#
#       daily_spend  revenue
# 0           11.79    70.50
# 1           11.61    78.00
# 2           12.03    85.80
# 3           12.87   104.70
# 4           12.88   101.70
# ...           ...      ...
# 1455        66.59   236.50
# 1456       104.60   349.75
# 1457        66.08   248.25
# 1458        49.36   214.00
# 1459        30.81   148.50
#
# [1460 rows x 11 columns]

# %%
# check for all the unique values in the item_group_id(campaign) col
df.item_group_id.unique()
# Out:
# array(['b5yn8r3', 's2dmtni', 'bwik4qv', '73t0r3u', 'wqgxoc1', 'u2t9dgi',
#        'uwyvrja', 'pace1ha', '36b7iyw'], dtype=object)

# %% [markdown]
# # Task 1
#
# Selected item_group_ids are ***b5yn8r3***, ***73t0r3u***, ***36b7iyw***

# %%
# Creating dataframes containing only the selected campaigns
dfB5 = df.loc[df["item_group_id"] == "b5yn8r3"]
df73 = df.loc[df["item_group_id"] == "73t0r3u"]
df36 = df.loc[df["item_group_id"] == "36b7iyw"]

# %%
# Create a plotting function
def plotLine(df, yAxisValue):
    campaignId = df["item_group_id"].unique()[0]
    a4Dims = (11.7, 8.27)
    fig, ax = plt.subplots(figsize=a4Dims)
    sns.lineplot(x="created_at", y=yAxisValue, hue="item_id", data=df, ci=None, ax=ax)
    plt.xticks(rotation=90)
    plt.title(f"item_group: {campaignId} vs {yAxisValue}")

# %% [markdown]
# ### item_group: b5yn8r3 engagement and conversion rate plots

# %%
# b5yn8
plotLine(dfB5, "num_engagements")

# %%
# clickthrough plot
plotLine(dfB5, "num_clickthroughs")

# %% [markdown]
# ### item_group: 73t0r3u engagement and conversion rate plots

# %%
plotLine(df73, "num_engagements")

# %%
plotLine(df73, "num_clickthroughs")

# %% [markdown]
# ### item_group: 36b7iyw engagement and conversion rate plots

# %%
plotLine(df36, "num_engagements")

# %%
plotLine(df36, "num_clickthroughs")

# %% [markdown]
# # Task 2

# %%
dfTask2 = pd.read_csv("../data/GLOBAL-461053 Adludio History 2021-02-26.csv")
dfTask2
# Out:
#                        modifiedon                         user  \
# 0     2021-02-19 15:32:05.1885877        angela.yu@adludio.com
# 1     2021-02-18 01:51:18.8845678        angela.yu@adludio.com
# 2     2021-02-12 17:15:49.9365387        angela.yu@adludio.com
# 3     2021-02-12 17:15:49.9365387        angela.yu@adludio.com
# 4     2021-02-12 17:15:49.9209108        angela.yu@adludio.com
# ...                           ...                          ...
# 3002  2020-08-30 08:18:17.1630000  abigail.gammell@adludio.com
# 3003  2020-08-30 05:04:27.6870000  abigail.gammell@adludio.com
# 3004  2020-08-30 05:04:27.6830000  abigail.gammell@adludio.com
# 3005  2020-08-30 05:04:19.8030000  abigail.gammell@adludio.com
# 3006  2020-08-30 05:04:19.7970000  abigail.gammell@adludio.com
#
#                table                          column             OldValue  \
# 0     CampaignFlight             EndDateExclusiveUTC  2021-02-23T04:59:00
# 1     CampaignFlight             EndDateExclusiveUTC  2021-03-01T04:59:00
# 2      AdGroupFlight      BudgetInAdvertiserCurrency          2980.000000
# 3      AdGroupFlight      BudgetInAdvertiserCurrency          2980.000000
# 4            AdGroup      BudgetInAdvertiserCurrency          6476.920000
# ...              ...                             ...                  ...
# 3002         AdGroup  BaseBidCPMInAdvertiserCurrency             4.000000
# 3003   AdGroupFlight      BudgetInAdvertiserCurrency            30.000000
# 3004         AdGroup      BudgetInAdvertiserCurrency            30.000000
# 3005   AdGroupFlight      BudgetInAdvertiserCurrency           150.000000
# 3006         AdGroup      BudgetInAdvertiserCurrency           150.000000
#
#                  NewValue primarykey secondarykey modifiedby  \
# 0     2021-02-22T04:59:00    rf33gwg      2023334    ttd_api
# 1     2021-02-23T04:59:00    rf33gwg      2023334    ttd_api
# 2             3874.000000    gehehl7      2037170    ttd_api
# 3             2086.000000    oropida      2037170    ttd_api
# 4             7370.920000    gehehl7       (null)    ttd_api
# ...                   ...        ...          ...        ...
# 3002             5.000000    unwvpjo       (null)    ttd_api
# 3003            40.000000    s1gj6o7      1635300    ttd_api
# 3004            40.000000    s1gj6o7       (null)    ttd_api
# 3005           170.000000    unwvpjo      1635300    ttd_api
# 3006           170.000000    unwvpjo       (null)    ttd_api
#
#                             source
# 0     .Net SqlClient Data Provider
# 1     .Net SqlClient Data Provider
# 2     .Net SqlClient Data Provider
# 3     .Net SqlClient Data Provider
# 4     .Net SqlClient Data Provider
# ...                            ...
# 3002  .Net SqlClient Data Provider
# 3003  .Net SqlClient Data Provider
# 3004  .Net SqlClient Data Provider
# 3005  .Net SqlClient Data Provider
# 3006  .Net SqlClient Data Provider
#
# [3007 rows x 10 columns]

# %%
dfTTD = dfTask2.loc[dfTask2["column"] == "BudgetInAdvertiserCurrency"]
dfTTD
# Out:
#                        modifiedon                         user  \
# 2     2021-02-12 17:15:49.9365387        angela.yu@adludio.com
# 3     2021-02-12 17:15:49.9365387        angela.yu@adludio.com
# 4     2021-02-12 17:15:49.9209108        angela.yu@adludio.com
# 5     2021-02-12 17:15:49.9209108        angela.yu@adludio.com
# 18    2021-02-11 12:23:11.9851841  ttd_api_ay6wyin@adludio.com
# ...                           ...                          ...
# 2998  2020-08-31 04:38:14.9370000  abigail.gammell@adludio.com
# 3003  2020-08-30 05:04:27.6870000  abigail.gammell@adludio.com
# 3004  2020-08-30 05:04:27.6830000  abigail.gammell@adludio.com
# 3005  2020-08-30 05:04:19.8030000  abigail.gammell@adludio.com
# 3006  2020-08-30 05:04:19.7970000  abigail.gammell@adludio.com
#
#                table                      column      OldValue      NewValue  \
# 2      AdGroupFlight  BudgetInAdvertiserCurrency   2980.000000   3874.000000
# 3      AdGroupFlight  BudgetInAdvertiserCurrency   2980.000000   2086.000000
# 4            AdGroup  BudgetInAdvertiserCurrency   6476.920000   7370.920000
# 5            AdGroup  BudgetInAdvertiserCurrency  13360.890000  12466.890000
# 18     AdGroupFlight  BudgetInAdvertiserCurrency    913.000000   1272.657729
# ...              ...                         ...           ...           ...
# 2998  CampaignFlight  BudgetInAdvertiserCurrency    300.000000    320.000000
# 3003   AdGroupFlight  BudgetInAdvertiserCurrency     30.000000     40.000000
# 3004         AdGroup  BudgetInAdvertiserCurrency     30.000000     40.000000
# 3005   AdGroupFlight  BudgetInAdvertiserCurrency    150.000000    170.000000
# 3006         AdGroup  BudgetInAdvertiserCurrency    150.000000    170.000000
#
#      primarykey secondarykey     modifiedby                        source
# 2       gehehl7      2037170        ttd_api  .Net SqlClient Data Provider
# 3       oropida      2037170        ttd_api  .Net SqlClient Data Provider
# 4       gehehl7       (null)        ttd_api  .Net SqlClient Data Provider
# 5       oropida       (null)        ttd_api  .Net SqlClient Data Provider
# 18      gq012j8      2023334  ttd_publicapi  .Net SqlClient Data Provider
# ...         ...          ...            ...                           ...
# 2998    wqgxoc1      1635300        ttd_api  .Net SqlClient Data Provider
# 3003    s1gj6o7      1635300        ttd_api  .Net SqlClient Data Provider
# 3004    s1gj6o7       (null)        ttd_api  .Net SqlClient Data Provider
# 3005    unwvpjo      1635300        ttd_api  .Net SqlClient Data Provider
# 3006    unwvpjo       (null)        ttd_api  .Net SqlClient Data Provider
#
# [824 rows x 10 columns]

# %%
# check for all values in the table column
dfTTD["table"].unique()
# Out:
# array(['AdGroupFlight', 'AdGroup', 'CampaignFlight', 'Campaign'],
#       dtype=object)

# %%
# Selected rows where the table column has the value AdGroup or AdGroupFlight
dfWanted = dfTTD.loc[(dfTTD["table"] == "AdGroup") | (dfTTD["table"] == "AdGroupFlight")]
dfWanted
# Out:
#                        modifiedon                         user          table  \
# 2     2021-02-12 17:15:49.9365387        angela.yu@adludio.com  AdGroupFlight
# 3     2021-02-12 17:15:49.9365387        angela.yu@adludio.com  AdGroupFlight
# 4     2021-02-12 17:15:49.9209108        angela.yu@adludio.com        AdGroup
# 5     2021-02-12 17:15:49.9209108        angela.yu@adludio.com        AdGroup
# 18    2021-02-11 12:23:11.9851841  ttd_api_ay6wyin@adludio.com  AdGroupFlight
# ...                           ...                          ...            ...
# 2972  2020-09-01 17:39:53.0170000        angela.yu@adludio.com        AdGroup
# 3003  2020-08-30 05:04:27.6870000  abigail.gammell@adludio.com  AdGroupFlight
# 3004  2020-08-30 05:04:27.6830000  abigail.gammell@adludio.com        AdGroup
# 3005  2020-08-30 05:04:19.8030000  abigail.gammell@adludio.com  AdGroupFlight
# 3006  2020-08-30 05:04:19.7970000  abigail.gammell@adludio.com        AdGroup
#
#                           column      OldValue      NewValue primarykey  \
# 2     BudgetInAdvertiserCurrency   2980.000000   3874.000000    gehehl7
# 3     BudgetInAdvertiserCurrency   2980.000000   2086.000000    oropida
# 4     BudgetInAdvertiserCurrency   6476.920000   7370.920000    gehehl7
# 5     BudgetInAdvertiserCurrency  13360.890000  12466.890000    oropida
# 18    BudgetInAdvertiserCurrency    913.000000   1272.657729    gq012j8
# ...                          ...           ...           ...        ...
# 2972  BudgetInAdvertiserCurrency   1413.890000   2624.890000    oropida
# 3003  BudgetInAdvertiserCurrency     30.000000     40.000000    s1gj6o7
# 3004  BudgetInAdvertiserCurrency     30.000000     40.000000    s1gj6o7
# 3005  BudgetInAdvertiserCurrency    150.000000    170.000000    unwvpjo
# 3006  BudgetInAdvertiserCurrency    150.000000    170.000000    unwvpjo
#
#      secondarykey     modifiedby                        source
# 2         2037170        ttd_api  .Net SqlClient Data Provider
# 3         2037170        ttd_api  .Net SqlClient Data Provider
# 4          (null)        ttd_api  .Net SqlClient Data Provider
# 5          (null)        ttd_api  .Net SqlClient Data Provider
# 18        2023334  ttd_publicapi  .Net SqlClient Data Provider
# ...           ...            ...                           ...
# 2972       (null)        ttd_api  .Net SqlClient Data Provider
# 3003      1635300        ttd_api  .Net SqlClient Data Provider
# 3004       (null)        ttd_api  .Net SqlClient Data Provider
# 3005      1635300        ttd_api  .Net SqlClient Data Provider
# 3006       (null)        ttd_api  .Net SqlClient Data Provider
#
# [578 rows x 10 columns]
